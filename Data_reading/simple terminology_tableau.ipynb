# %%
import pandas as pd 
import os

# %%
k=os.listdir('D:/watcho requests')

# %%
file= [ 'D:/watcho requests'+'/'+ i for i in k ]
file
# Out:
# ['D:/watcho requests/temp_20240226_00001',
#  'D:/watcho requests/temp_20240227_00001',
#  'D:/watcho requests/temp_20240228_00001',
#  'D:/watcho requests/temp_20240229_00001',
#  'D:/watcho requests/temp_20240301_00001',
#  'D:/watcho requests/temp_20240302_00001',
#  'D:/watcho requests/temp_20240303_00001',
#  'D:/watcho requests/temp_20240304_00001',
#  'D:/watcho requests/temp_20240305_00001',
#  'D:/watcho requests/temp_20240306_00001',
#  'D:/watcho requests/temp_20240307_00001',
#  'D:/watcho requests/temp_20240308_00001',
#  'D:/watcho requests/temp_20240309_00001',
#  'D:/watcho requests/temp_20240310_00001',
#  'D:/watcho requests/temp_20240311_00001',
#  'D:/watcho requests/temp_20240312_00001',
#  'D:/watcho requests/temp_20240313_00001',
#  'D:/watcho requests/temp_20240314_00001',
#  'D:/watcho requests/temp_20240315_00001',
#  'D:/watcho requests/temp_20240316_00001',
#  'D:/watcho requests/temp_20240317_00001',
#  'D:/watcho requests/temp_20240318_00001',
# ...

# %%
k=[]
for i in file :

    p=[ i+'/' +j for j in os.listdir(i)]
    k.extend(p)

# %%
k
# Out:
# ['D:/watcho requests/temp_20240226_00001/events_20240226_0000000001.csv',
#  'D:/watcho requests/temp_20240226_00001/events_20240226_0000000002.csv',
#  'D:/watcho requests/temp_20240226_00001/events_20240226_0000000003.csv',
#  'D:/watcho requests/temp_20240226_00001/events_20240226_0000000004.csv',
#  'D:/watcho requests/temp_20240226_00001/events_20240226_0000000005.csv',
#  'D:/watcho requests/temp_20240226_00001/events_20240226_0000000006.csv',
#  'D:/watcho requests/temp_20240226_00001/events_20240226_0000000007.csv',
#  'D:/watcho requests/temp_20240226_00001/events_20240226_0000000008.csv',
#  'D:/watcho requests/temp_20240227_00001/events_20240227_0000000001.csv',
#  'D:/watcho requests/temp_20240227_00001/events_20240227_0000000002.csv',
#  'D:/watcho requests/temp_20240227_00001/events_20240227_0000000003.csv',
#  'D:/watcho requests/temp_20240227_00001/events_20240227_0000000004.csv',
#  'D:/watcho requests/temp_20240227_00001/events_20240227_0000000005.csv',
# ...

# %%
pd.concat([ pd.read_csv(i,sep='\t') for i in k ])
# Out:
#                userid        projectid        content_id content_type  \
# 0     1705713_1752254  T3k-Yoj-ex9-JE0  833162_tvepisode    tvepisode
# 1     4231664_4370539  T3k-Yoj-ex9-JE0            6_live         live
# 2                -1_0  T3k-Yoj-ex9-JE0     432_tvepisode    tvepisode
# 3     4374453_4534946  T3k-Yoj-ex9-JE0           16_live         live
# 4     4374453_4534946  T3k-Yoj-ex9-JE0           16_live         live
# ...               ...              ...               ...          ...
# 2763  5532403_5740088  T3k-Yoj-ex9-JE0           32_live         live
# 2764  5532403_5740088  T3k-Yoj-ex9-JE0        31340_live         live
# 2765  5398424_5597857  T3k-Yoj-ex9-JE0       29254_movie        movie
# 2766  5532403_5740088  T3k-Yoj-ex9-JE0           21_live         live
# 2767      13353_13357  T3k-Yoj-ex9-JE0       36907_movie        movie
#
#      originmedium                          originname  originsource  \
# ...
